# %% [markdown]
# # Inicio
#
# Este libro digital tiene como objetivo reunir de forma resumida, simplificada e interactiva, los contenidos de **ciencias básicas** correspondientes al plan de [Bachillerato en Ciencias de la Ingeniería](https://www.uach.cl/dw/admision/plandeestudio.php?car=1807) (Plan Común).
#
# Este proyecto está en constante desarrollo. El código fuente se encuentra en: https://github.com/aretesatori/ciencias-basicas-ingenieria.
#
# Los contenidos que se encuentran a continuación están basados específicamente en los programas de las asignaturas de plan común (vigentes al año 2024), impartidas a las carreras de ingeniería por la [Universidad Austral de Chile](https://ingenieria.uach.cl/).
#
# <!--Este recurso fue desarrollado utilizando el entorno Jupyter Notebook, para posteriormente ser exportado en formato de página web utilizando Sphinx y una plantilla predeterminada. Se han utilizado principalmente los lenguajes Markdown y HTML para la estructura, Python para cargar las aplicaciones interactivas, LaTeX para generar las ecuaciones y símbolos, CSS y Javascript. Se requiere del uso de MathJax para renderizar el código LaTeX en el navegador web. -->
#
# ---
# # Asignaturas
#
# ## Álgebra para Ingeniería
#
# ### Contenido (BAIN065-24)
#
# - **Unidad 1:** [Números Reales y Lenguaje Algebraico](https://aretesatori.github.io/ciencias-basicas-ingenieria/books/BAIN065-24/1-BAIN065-24.html)
# - **Unidad 2:** [Ecuaciones Algebraicas](https://aretesatori.github.io/ciencias-basicas-ingenieria/books/BAIN065-24/2-BAIN065-24.html)
# - **Unidad 3:** [Polinomios con Coeficientes Reales](https://aretesatori.github.io/ciencias-basicas-ingenieria/books/BAIN065-24/3-BAIN065-24.html)
# - **Unidad 4:** [Lógica y Conjuntos](https://aretesatori.github.io/ciencias-basicas-ingenieria/books/BAIN065-24/4-BAIN065-24.html)
# - **Unidad 5:** Orden en los Números Reales
# - **Unidad 6:** Funciones Reales
# - **Unidad 7:** Límites y Continuidad
#
# ## Geometría para Ingeniería
#
# ### Contenido (BAIN067-24)
#
# - **Unidad 1:** Geometría Plana
# - **Unidad 2:** Geometría Analítica
# - **Unidad 3:** Geometría Vectorial
# - **Unidad 4:** Funciones Trigonométricas, Coordenadas Polares y Números Complejos
#
# ## Química para Ingeniería
#
# ### Contenido (BAIN069-24)
#
# - **\[No disponible\]**
#
# ---
# # Bibliografía
#
# * SiveducMD (https://siveducmd.uach.cl/).
# * Mikenberg, I. F. (2013). [Álgebra e Introducción al Cálculo](https://www.ing.uc.cl/wp-content/uploads/2017/07/Prec%C3%A1lculo.pdf). Pontificia Universidad Católica de Chile.
# * GeoGebra. (https://www.geogebra.org/u/aretesatori).
#
# ---
# # Contacto
#
# Cualquier sugerencia, contribución y/o comentario es bienvenido.
# * Correo electrónico: [arete.poffart@alumnos.uach.cl](mailto:arete.poffart@alumnos.uach.cl)
#
# ---
# # Agradecimiento
#
# > $$\bigstar\quad\bigstar\quad\bigstar\quad\bigstar\quad\bigstar$$
# > * **Un agradecimiento especial al profesor Pablo Huijse:** por desarrollar y disponibilizar la plantilla de construcción de libros interactivos en Jupyter Notebook.
# > * Repositorio del proyecto: https://github.com/phuijse/JupyterBookUACh
# >
# > $$\bigstar\quad\bigstar\quad\bigstar\quad\bigstar\quad\bigstar$$
