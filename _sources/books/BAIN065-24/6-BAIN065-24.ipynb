# %% [markdown]
# # Funciones de Variable Real
#
# ## Definición de Función
#
# Sean $A$ y $B$ dos conjuntos no vacíos. Una función de $A$ en $B$ es una correspondencia tal que a cada elemento de $A$ le corresponde un único elemento de $B$.
#
# Viene dado por la siguiente definición:
#
# $$\begin{array}{cl}
#     f : & A & \longrightarrow & B & \\
#         & x & \longmapsto & y = f(x) &
# \end{array}$$
#
# $$(\forall x \in A)(\exists! y \in B)(f(x) = y)$$
#
# <!--
# >$f : \quad A \rightarrow B$
# >
# >$(\forall a \in A)(\exists! b \in B)$ ($f(a) = b$) -->
#
#
# Para las funciones de variable real, $A$ y $B$ son subconjuntos de $\mathbb{R}$ y tienen la siguiente definición:
#
# $$\begin{align}
#     f : \quad A  \subseteq\mathbb{R}&\; \longrightarrow B \subseteq\mathbb{R} \\
#         x &\; \longmapsto y = f(x)
# \end{align}$$
#
# :::{note} **Notación:**
#
# $\begin{array}{rcl}
#   &\; \forall  &\; \text{: Para todo.} \\ \\
#   &\; \exists! &\; \text{: Existe un único.} \\ \\
#   &\; A \subseteq B &\; \text{: A subconjunto de B.}
# \end{array}$
#
# <!-- * $\forall$: _Para todo._
#
# * $\exists!$: $\quad$_Existe un único._
#
# * $A \subseteq B$: $\quad$_A Subconjunto de B._ -->
#
# :::
#
# ### Diagrama Sagital

# %% [markdown]
# <iframe scrolling="no" title="Correspondencia de Funciones" src="https://www.geogebra.org/material/iframe/id/acrkjzme/width/750/height/580/border/888888/sfsb/true/smb/false/stb/false/stbh/false/ai/false/asb/false/sri/false/rc/false/ld/false/sdz/false/ctl/false" width="49%" height="300" style="border: 0px;"></iframe>
# <iframe scrolling="no" title="Correspondencia de Funciones" src="https://www.geogebra.org/material/iframe/id/bedgnh6z/width/750/height/580/border/888888/sfsb/true/smb/false/stb/false/stbh/false/ai/false/asb/false/sri/false/rc/false/ld/false/sdz/false/ctl/false" width="49%" height="300" style="border: 0px;"></iframe>
#
# > Recurso 1: https://www.geogebra.org/graphing/acrkjzme
# > Recurso 2: https://www.geogebra.org/graphing/bedgnh6z
#
# En el primer diagrama, _cada elemento de $A$ tiene una correspondencia con un único elemento de $B$_, lo que cumple con la definición de función.
#
# En el caso del segundo diagrama, existe un elemento del conjunto $A$ que tiene una correspondencia con más de un elemento del conjunto $B$, lo que no cumple con la definición de función.

# %% [markdown]
# ## Elementos de una Función
#
# <!-- $$
# a + b + c = \underbrace{(a + b) + c}_{\text{Anotación horizontal inferior}}
# $$
#
#
# $$
# a + b + c = \overbrace{a + (b + c)}^{\text{Anotación horizontal superior}}
# $$ -->
#
# $$\begin{array}{rcc}
#     f : &\; \overbrace{A}^{\text{Dominio}} \longrightarrow &\; \overbrace{B}^{\text{Codominio}} &\;\\
#        &\; \underbrace{x}_{\text{Preimagen}} \longmapsto &\; \underbrace{y = f(x)}_{\text{Regla de Correspondencia}} &\;
# \end{array}$$
#
# * $A$ se llama **Dominio** de la función o **Conjunto de Partida**.
# * $B$ se llama **Codominio** de la función o **Conjunto de Llegada**.
# * $y = f(x)$ se llama **Regla de Correspondencia**.
# * $x$ se llama **Preimagen** o **Variable Independiente**.
# * $y$ se llama **Imagen** o **Variable Dependiente**.

# %%
from IPython.display import HTML

HTML('<iframe scrolling="no" title="Correspondencia de Funciones" src="https://www.geogebra.org/material/iframe/id/ykuydbak/width/830/height/580/border/888888/sfsb/true/smb/false/stb/false/stbh/false/ai/false/asb/false/sri/false/rc/false/ld/false/sdz/false/ctl/false" width="100%" height="600" style="border: 0px; border: 3px solid gray; /*Border only for debug*/ "></iframe>')
# Out:
# <iframe scrolling="no" title="Correspondencia de Funciones" src="https://www.geogebra.org/material/iframe/id/ykuydbak/width/830/height/580/border/888888/sfsb/true/smb/false/stb/false/stbh/false/ai/false/asb/false/sri/false/rc/false/ld/false/sdz/false/ctl/false" width="100%" height="600" style="border: 0px; border: 3px solid gray; /*Border only for debug*/ "></iframe>

# %% [markdown]
# ## Dominio de una Función
#
# Sea $\quad\boxed{\begin{align}
#     f : \quad A  \subseteq\mathbb{R}&\; \longrightarrow B \subseteq\mathbb{R} \\
#         x &\; \longmapsto y = f(x)
# \end{align}}\quad$ una función, el Dominio de $f$ denotado por $Dom(f)$ se define como:
#
# $$\boxed{Dom(f) = \{x \in\mathbb{R} : f(x) \in\mathbb{R}\}}$$
#
# ## Recorrido de una Función
#
# Sea $\quad\boxed{\begin{align}
#     f : \quad &\; A \longrightarrow B \\
#        &\; x \longmapsto y = f(x)
# \end{align}}\quad$ una función, el Recorrido de $f$ denotado por $Rec(f)$ se define como:
#
# $$\boxed{Rec(f) = \{y \in\mathbb{R} : (\exists x \in Dom(f))(y = f(x))\}}$$

# %% [markdown]
# ## Álgebra de Funciones
#
# ## Composición de Funciones
#
# $(g \circ f)(x) = g\left( f(x) \right)$
#
#
# $Dom(g \circ f) = \{x \in Dom(f) : f(x) \in Dom(g)\}$

# %% [markdown]
# ## Tipos de Funciones
#
#
# ## Inyectividad
#
# Sea $\quad\boxed{\begin{align}
#     f : \quad &\; A \longrightarrow \mathbb{R} \\
#        &\; x \longmapsto y = f(x)
# \end{align}}\quad$ una función. Diremos que $f$ es **inyectiva**, si y solo si:
#
# $$\forall a, b \in A = Dom(f)$$
#
# $$f(a) = f(b) \Rightarrow a = b$$
#
#
# ## Sobreyectividad
#
#
# ## Función Inversa

# %% [markdown]
# ## GeoGebra
#
# Calculadora gráfica interactiva.
#
# <iframe height="700" width="100%" style="border: 2px solid gray; padding: 1%; border-radius: 1em;" scrolling="no" title="GeoGebra" src="https://www.geogebra.org/graphing" frameborder="no" loading="lazy" allowtransparency="true" allowfullscreen="true"></iframe>
#
# > Recurso: https://www.geogebra.org/graphing

# %% [markdown]
# ## Gráfico de Funciones Conocidas
#
# ### Función Constante
#
# Es una función que siempre toma la misma imagen para cualquier valor de x. Tiene la forma $\boxed{f(x) = k}$ o también $\boxed{y = k}$, donde $k$ es un número real cualquiera.
#
# $\large \boxed{f(x) = k} \small\quad\quad (k \in \mathbb{R})$
#
# * El dominio de la función constante es el conjunto de los números reales:
#
# > $Dom(f) = \mathbb{R}$
#
# * El recorrido de la función constante es el valor de la constante:
#
# > $Rec(f) = k$
#
# * Ejemplo:
#
# > $f(x) = 1$
#
# <iframe height="500" style="width: 100%;" scrolling="no" title="Función Constante" src="https://www.geogebra.org/material/iframe/id/n2r2mp9w/width/1000/height/600/border/888888/sfsb/true/smb/false/stb/false/stbh/false/ai/false/asb/false/sri/false/rc/false/ld/false/sdz/false/ctl/false" frameborder="no" loading="lazy" allowtransparency="true" allowfullscreen="true"></iframe>
#
# > Recurso: https://www.geogebra.org/graphing/n2r2mp9w
#
# ### Función Identidad
#
# $\large \boxed{f(x) = x}$
#
# > $Dom(f) = \mathbb{R}$
#
# > $Rec(f) = \mathbb{R}$
#
# <iframe height="500" style="width: 100%;" scrolling="no" title="Función Identidad" src="https://www.geogebra.org/material/iframe/id/d9t8qsve/width/1000/height/600/border/888888/sfsb/true/smb/false/stb/false/stbh/false/ai/false/asb/false/sri/false/rc/false/ld/false/sdz/false/ctl/false" frameborder="no" loading="lazy" allowtransparency="true" allowfullscreen="true"></iframe>
#
# > Recurso: https://www.geogebra.org/graphing/d9t8qsve
#
# ### Función Valor Absoluto
#
# $\large \boxed{f(x) = |x|}$
#
# > $Dom(f) = \mathbb{R}$
#
# > $Rec(f) = [0, +\infty[ \quad=\quad \mathbb{R_0}^+$
#
# <iframe height="500" style="width: 100%;" scrolling="no" title="Función Valor Absoluto" src="https://www.geogebra.org/material/iframe/id/j3gss6gj/width/1000/height/600/border/888888/sfsb/true/smb/false/stb/false/stbh/false/ai/false/asb/false/sri/false/rc/false/ld/false/sdz/false/ctl/false" frameborder="no" loading="lazy" allowtransparency="true" allowfullscreen="true"></iframe>
#
# > Recurso: https://www.geogebra.org/graphing/j3gss6gj
#
# ### Función Cuadrática
#
# $\large \boxed{f(x) = x^2}$
#
# > $Dom(f) = \mathbb{R}$
#
# > $Rec(f) = [0, +\infty[ \quad=\quad \mathbb{R_0}^+$
#
# <iframe height="500" style="width: 100%;" scrolling="no" title="Función Cuadrática" src="https://www.geogebra.org/material/iframe/id/pcvnmnen/width/1000/height/600/border/888888/sfsb/true/smb/false/stb/false/stbh/false/ai/false/asb/false/sri/false/rc/false/ld/false/sdz/false/ctl/false" frameborder="no" loading="lazy" allowtransparency="true" allowfullscreen="true"></iframe>
#
# > Recurso: https://www.geogebra.org/graphing/pcvnmnen
#
# ### Función Cúbica
#
# $\large \boxed{f(x) = x^3}$
#
# > $Dom(f) = \mathbb{R}$
#
# > $Rec(f) = \mathbb{R}$
#
# <iframe height="500" style="width: 100%;" scrolling="no" title="Función Cúbica" src="https://www.geogebra.org/material/iframe/id/r93mgzmp/width/1000/height/600/border/888888/sfsb/true/smb/false/stb/false/stbh/false/ai/false/asb/false/sri/false/rc/false/ld/false/sdz/false/ctl/false" frameborder="no" loading="lazy" allowtransparency="true" allowfullscreen="true"></iframe>
#
# > Recurso: https://www.geogebra.org/graphing/r93mgzmp
#
# ### Función Radical
#
# $\large \boxed{f(x) = \sqrt{x}}$
#
# > $Dom(f) = [0, +\infty[ \quad=\quad \mathbb{R_0}^+$
#
# > $Rec(f) = [0, +\infty[ \quad=\quad \mathbb{R_0}^+$
#
# <iframe height="500" style="width: 100%;" scrolling="no" title="Función Radical" src="https://www.geogebra.org/material/iframe/id/za28whut/width/1000/height/600/border/888888/sfsb/true/smb/false/stb/false/stbh/false/ai/false/asb/false/sri/false/rc/false/ld/false/sdz/false/ctl/false" frameborder="no" loading="lazy" allowtransparency="true" allowfullscreen="true"></iframe>
#
# > Recurso: https://www.geogebra.org/graphing/za28whut
#
# ### Función Racional
#
# $\large \boxed{f(x) = \frac{1}{x}}$
#
# > $Dom(f) = \mathbb{R} - \{0\}$
#
# > $Rec(f) = \mathbb{R} - \{0\}$
#
# <iframe height="500" style="width: 100%;" scrolling="no" title="Función Racional" src="https://www.geogebra.org/material/iframe/id/khtauugy/width/1000/height/600/border/888888/sfsb/true/smb/false/stb/false/stbh/false/ai/false/asb/false/sri/false/rc/false/ld/false/sdz/false/ctl/false" frameborder="no" loading="lazy" allowtransparency="true" allowfullscreen="true"></iframe>
#
# > Recurso: https://www.geogebra.org/graphing/khtauugy
#
# ### Función Seno
#
# $\large \boxed{f(x) = \sin{(x)}}$
#
# > $Dom(f) = \mathbb{R}$
#
# > $Rec(f) = [-1, 1]$
#
# <iframe height="500" style="width: 100%;" scrolling="no" title="Función Seno" src="https://www.geogebra.org/material/iframe/id/jfsjehxt/width/1000/height/600/border/888888/sfsb/true/smb/false/stb/false/stbh/false/ai/false/asb/false/sri/false/rc/false/ld/false/sdz/false/ctl/false" frameborder="no" loading="lazy" allowtransparency="true" allowfullscreen="true"></iframe>
#
# > Recurso: https://www.geogebra.org/graphing/jfsjehxt
#
# ### Función Exponencial
#
# $\large \boxed{f(x) = a^x} \small\quad\quad (a \in \mathbb{R}^+ - \{1\})$
#
# > $Dom(f) = \mathbb{R}$
#
# > $Rec(f) = ]0, +\infty[ \quad=\quad \mathbb{R}^+$
#
# <iframe height="500" style="width: 100%;" scrolling="no" title="Función Exponencial" src="https://www.geogebra.org/material/iframe/id/w4gk8u3k/width/1000/height/600/border/888888/sfsb/true/smb/false/stb/false/stbh/false/ai/false/asb/false/sri/false/rc/false/ld/false/sdz/false/ctl/false" frameborder="no" loading="lazy" allowtransparency="true" allowfullscreen="true"></iframe>
#
# > Recurso: https://www.geogebra.org/graphing/w4gk8u3k
#
# ### Función Logarítmica
#
# $\large \boxed{f(x) = \log{(x)}}$
#
# <iframe height="500" style="width: 100%;" scrolling="no" title="Función Logarítmica" src="https://www.geogebra.org/material/iframe/id/dzxzsu9k/width/1000/height/600/border/888888/sfsb/true/smb/false/stb/false/stbh/false/ai/false/asb/false/sri/false/rc/false/ld/false/sdz/false/ctl/false" frameborder="no" loading="lazy" allowtransparency="true" allowfullscreen="true"></iframe>
#
# > Recurso: https://www.geogebra.org/graphing/dzxzsu9k
